# %% [markdown]
# # Having a look at the data
#
#
# ## River levels

# %%
# packages
import pandas as pd
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display
from load_levels import load_levels

# %%
# Load the hydrology data
file_path = '../data/river/Todmorden-Callis-Bridge-level-15min-Qualified.csv'
df = load_levels(file_path)

# Convert dateTime column to datetime format
df['dateTime'] = pd.to_datetime(df['dateTime'], errors='coerce')

# Add a 'season' column based on month
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Autumn'

df['season'] = df['dateTime'].dt.month.map(get_season)
df
# Out:
#      measure            dateTime        date  value                  station  \
# 0      level 2025-08-16 00:00:00  2025-08-16 -0.025  Todmorden-Callis-Bridge
# 1      level 2025-08-16 00:15:00  2025-08-16 -0.025  Todmorden-Callis-Bridge
# 2      level 2025-08-16 00:30:00  2025-08-16 -0.025  Todmorden-Callis-Bridge
# 3      level 2025-08-16 00:45:00  2025-08-16 -0.026  Todmorden-Callis-Bridge
# 4      level 2025-08-16 01:00:00  2025-08-16 -0.025  Todmorden-Callis-Bridge
# ...      ...                 ...         ...    ...                      ...
# 2738   level 2025-09-13 13:15:00  2025-09-13 -0.030  Todmorden-Callis-Bridge
# 2739   level 2025-09-13 13:30:00  2025-09-13 -0.030  Todmorden-Callis-Bridge
# 2740   level 2025-09-13 13:45:00  2025-09-13 -0.030  Todmorden-Callis-Bridge
# 2741   level 2025-09-13 14:00:00  2025-09-13 -0.030  Todmorden-Callis-Bridge
# 2742   level 2025-09-13 14:15:00  2025-09-13 -0.030  Todmorden-Callis-Bridge
#
#       season
# 0     Summer
# 1     Summer
# 2     Summer
# 3     Summer
# 4     Summer
# ...      ...
# 2738  Autumn
# 2739  Autumn
# 2740  Autumn
# 2741  Autumn
# 2742  Autumn
#
# [2743 rows x 6 columns]

# %%
# simple plot

# Create a line plot of water level over time for multiple stations
fig = px.line(df, x='dateTime', y='value', color='station',
              labels={'dateTime': 'Date and Time', 'value': 'Water Level (m)', 'station': 'Monitoring Station'},
              title='Water Level Over Time by Monitoring Station')

# Show the plot
fig.show()
